# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2 
from sklearn.ensemble import ExtraTreesClassifier
from mpl_toolkits.mplot3d import Axes3D
import tabulate
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
X_data = pd.read_csv('training_data.csv')
Y_data = pd.read_csv('train_data_classlabels.csv')
testing_X_data = pd.read_csv('testing_data.csv')

# %%
print('Number Of Data Instances : ', X_data.shape[0])
print('Number Of Features : ', X_data.shape[1])
# Out:
# Number Of Data Instances :  57116
# Number Of Features :  30

# %%
X_data.isna().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# dtype: int64

# %%
X_data
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 0      50920  1.086640  0.148385  0.120522  0.974415 -0.035925 -0.406007
# 1      34737  1.294054  0.152664  0.195524  0.540694 -0.267245 -0.691144
# 2      11090 -0.352305  0.614321  2.000903 -0.403523 -0.409279 -0.395518
# 3      23194 -2.049784  1.004759  1.726403  1.600998 -1.121759  0.421037
# 4      38531 -0.289738  0.880936  1.787349  0.887265  0.125174 -0.845201
# ...      ...       ...       ...       ...       ...       ...       ...
# 57111  31552  0.458761 -2.050144 -0.466434 -0.042731 -1.449051 -0.904008
# 57112  42544  0.954816 -0.719838  0.901751  0.080120 -0.814359  0.654128
# 57113  41172 -0.926829 -0.886473  2.370167  0.300101 -2.076338  1.149399
# 57114  41560  0.939876 -0.143305  0.409470  1.401199 -0.315610  0.041466
# 57115  52909  1.591900 -0.850352 -0.434399 -1.617696 -0.773801 -0.653197
#
#              V7        V8        V9  ...       V20       V21       V22  \
# 0      0.270339 -0.139679 -0.411854  ...  0.086793  0.112405  0.221430
# 1      0.001673 -0.175527  0.179203  ... -0.087916  0.055098  0.213211
# 2      0.094420  0.066611  0.995869  ... -0.059598  0.055236  0.312846
# 3     -0.768145  1.133876  1.207850  ...  0.155066  0.085733  0.445599
# 4      1.256896 -0.632290 -0.260688  ...  0.073293  0.062741  0.503452
# ...         ...       ...       ...  ...       ...       ...       ...
# 57111  0.379405 -0.383444 -0.750893  ...  0.452662 -0.160474 -1.002111
# 57112 -0.647104  0.285089  0.819952  ...  0.173407 -0.105128 -0.227548
# 57113  0.555557  0.376249  1.209615  ...  0.599251  0.165073  0.376110
# 57114  0.057357  0.118171  0.069849  ... -0.036664  0.011079  0.015211
# 57115 -0.621472 -0.194046 -2.318691  ... -0.376931 -0.181145 -0.149442
#
#             V23       V24       V25       V26       V27       V28  Amount
# 0     -0.226960  0.046246  0.708183 -0.336475  0.002364  0.021463   76.10
# 1     -0.163730 -0.064862  0.606466  0.504450 -0.033823  0.006327    5.95
# 2     -0.146312  0.317882 -0.307554  0.975876 -0.047407  0.033127   14.95
# 3     -0.234451  0.040248  0.325920 -0.050118  0.257527 -0.015911   76.60
# 4     -0.202127  0.709686 -0.190366 -0.386543 -0.305748 -0.307859   30.54
# ...         ...       ...       ...       ...       ...       ...     ...
# 57111 -0.428028  0.451232  0.230248  1.041581 -0.165922  0.081869  496.74
# 57112 -0.042204 -0.192197  0.070007  0.961082 -0.034767  0.016900  109.12
# 57113  0.677804  0.472248 -0.166598  1.069099 -0.068823  0.045220  333.00
# 57114 -0.121116  0.225331  0.559770 -0.350135  0.017372  0.021977   94.90
# 57115 -0.159295 -0.363457  0.727830 -0.054879 -0.009193 -0.014170    0.01
#
# [57116 rows x 30 columns]

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# # Feature Selection Using Correlation Matrix And HeatMap

# %% [markdown]
# Here we have tried to use correlation matrix to understand how well features are correlated to target variable Y_data. For this purpose, we generate heatmap that will help us in understanding the correlation. Since the number of features are 30, we are going to create 3 maps just for the purpose of clarity and understanding. The inferences remain same.

# %%
X_map_1_data = X_data.iloc[:,0:10]
X_map_2_data = X_data.iloc[:,10:20]
X_map_3_data = X_data.iloc[:,20:30]
X_map_1_data.insert(10,'Y',Y_data,True)
X_map_2_data.insert(10,'Y',Y_data,True)
X_map_3_data.insert(10,'Y',Y_data,True)

# %% [markdown]
# # First 10 Features

# %%
plt.figure(figsize=(20,20))
corr = X_map_1_data.corr()
map_1 = sns.heatmap(corr,annot=True)

# %% [markdown]
# Now we can see that for the first 10 features V2, V4 and V8 are the ones that correlate most with target variabe Y.

# %% [markdown]
# # Next 10 Features

# %%
plt.figure(figsize=(20,20))
corr = X_map_2_data.corr()
map_2 = sns.heatmap(corr,annot=True)

# %% [markdown]
# For these set of features, V11 shows high correlation with target variable Y in comparison to others.

# %% [markdown]
# # Last 10 Features

# %%
plt.figure(figsize=(20,20))
corr = X_map_3_data.corr()
map_3 = sns.heatmap(corr,annot=True)

# %% [markdown]
# In the last 10 features, we can see that the correlation of Y with any other feature is quite low. After all 3 maps, we can see that not a very good distinction can be made for choice of best features. Therefore we need a better way of choosing optimum features.

# %% [markdown]
# # Feature Selection Using Extra Tree Classifier

# %% [markdown]
# Extra Tree Classifier (Also known as Extremely Randomized Tree Classifier) is a type of ensemble learning technique which aggregates the results of multiple de-correlated decision trees collected in a “forest” to output it’s classification result. In concept, it is very similar to a Random Forest Classifier and only differs from it in the manner of construction of the decision trees in the forest. It calculates importance of each feature and selects top K features with maximum importance. For our problem, K <= 30.

# %%
plt.figure(figsize=(16,10))
model = ExtraTreesClassifier()
model.fit(X_data,Y_data)
importances = model.feature_importances_
importance_normalised = np.std([tree.feature_importances_ for tree in model.estimators_],axis = 0)
plt.bar(X_data.columns, importance_normalised)
plt.xlabel('Features')
plt.ylabel('Feature Importances')
plt.title('Comparison of different Feature Importances')
plt.show()

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.preprocessing import StandardScaler          # Feature Scaling And Normalisation
scaler = StandardScaler()
scaler.fit_transform(X_data)
# Out:
# array([[ 1.09419212e+00,  7.15885599e-01,  1.04500665e-01, ...,
#         -1.14995373e-03,  6.86746789e-02, -7.70722076e-02],
#        [-1.68978011e-02,  8.27157193e-01,  1.07124325e-01, ...,
#         -9.65706868e-02,  1.74308323e-02, -3.36493536e-01],
#        [-1.64044988e+00, -5.60669338e-02,  3.90172161e-01, ...,
#         -1.32391123e-01,  1.08162568e-01, -3.03210685e-01],
#        ...,
#        [ 4.24915437e-01, -3.64282369e-01, -5.29984450e-01, ...,
#         -1.88863958e-01,  1.49102646e-01,  8.72968266e-01],
#        [ 4.51554681e-01,  6.37150715e-01, -7.43380906e-02, ...,
#          3.84261563e-02,  7.04148971e-02, -7.54803125e-03],
#        [ 1.23075257e+00,  9.86943015e-01, -5.07837816e-01, ...,
#         -3.16234048e-02, -5.19591538e-02, -3.58460217e-01]])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X_data,Y_data,test_size=0.30,random_state=42)

# %%
clf = RandomForestClassifier()
clf.fit(X_train,Y_train)
# Out:
# RandomForestClassifier()

# %%
preds = clf.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(Y_test,preds)
# Out:
# array([[17094,     3],
#        [    4,    34]])

# %%
print("Accuracy Of The Model : {} %".format(100*clf.score(X_data,Y_data)))
# Out:
# Accuracy Of The Model : 99.9877442397927 %

# %%
testing_X_data = testing_X_data.dropna()

# %%
testing_X_data.isna().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# dtype: int64

# %%
predictions = clf.predict(testing_X_data)

# %%
predictions
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
ones = sum(predictions == 1)

# %%
ones
# Out:
# 26

# %%
zeros = sum(predictions == 0)

# %%
zeros
# Out:
# 14251
